# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("Ransomware.csv",sep='|')

# %%
data
# Out:
#                                                Name  \
# 0                                       memtest.exe
# 1                                           ose.exe
# 2                                         setup.exe
# 3                                          DW20.EXE
# 4                                      dwtrig20.exe
# ...                                             ...
# 138042  VirusShare_8e292b418568d6e7b87f2a32aee7074b
# 138043  VirusShare_260d9e2258aed4c8a3bbd703ec895822
# 138044  VirusShare_8d088a51b7d225c9f5d11d239791ec3f
# 138045  VirusShare_4286dccf67ca220fe67635388229a9f3
# 138046  VirusShare_d7648eae45f09b3adb75127f43be6d11
#
#                                      md5  Machine  SizeOfOptionalHeader  \
# 0       631ea355665f28d4707448e442fbf5b8      332                   224
# 1       9d10f99a6712e28f8acd5641e3a7ea6b      332                   224
# 2       4d92f518527353c0db88a70fddcfd390      332                   224
# ...

# %%
data['legitimate'].value_counts()
# Out:
# 0    96724
# 1    41323
# Name: legitimate, dtype: int64

# %%
data.columns
# Out:
# Index(['Name', 'md5', 'Machine', 'SizeOfOptionalHeader', 'Characteristics',
#        'MajorLinkerVersion', 'MinorLinkerVersion', 'SizeOfCode',
#        'SizeOfInitializedData', 'SizeOfUninitializedData',
#        'AddressOfEntryPoint', 'BaseOfCode', 'BaseOfData', 'ImageBase',
#        'SectionAlignment', 'FileAlignment', 'MajorOperatingSystemVersion',
#        'MinorOperatingSystemVersion', 'MajorImageVersion', 'MinorImageVersion',
#        'MajorSubsystemVersion', 'MinorSubsystemVersion', 'SizeOfImage',
#        'SizeOfHeaders', 'CheckSum', 'Subsystem', 'DllCharacteristics',
#        'SizeOfStackReserve', 'SizeOfStackCommit', 'SizeOfHeapReserve',
#        'SizeOfHeapCommit', 'LoaderFlags', 'NumberOfRvaAndSizes', 'SectionsNb',
#        'SectionsMeanEntropy', 'SectionsMinEntropy', 'SectionsMaxEntropy',
#        'SectionsMeanRawsize', 'SectionsMinRawsize', 'SectionMaxRawsize',
#        'SectionsMeanVirtualsize', 'SectionsMinVirtualsize',
# ...

# %%
nonlegitimate=data[data['legitimate']==0]

# %%
nonlegitimate
# Out:
#                                                Name  \
# 41323   VirusShare_4a400b747afe6547e09ce0b02dae7f1c
# 41324   VirusShare_9bd57c8252948bd2fa651ad372bd4f13
# 41325   VirusShare_d1456165e9358b8f61f93a5f2042f39c
# 41326   VirusShare_e4214cc73afbba0f52bb72d5db8f8bb1
# 41327   VirusShare_710890c07b3f93b90635f8bff6c34605
# ...                                             ...
# 138042  VirusShare_8e292b418568d6e7b87f2a32aee7074b
# 138043  VirusShare_260d9e2258aed4c8a3bbd703ec895822
# 138044  VirusShare_8d088a51b7d225c9f5d11d239791ec3f
# 138045  VirusShare_4286dccf67ca220fe67635388229a9f3
# 138046  VirusShare_d7648eae45f09b3adb75127f43be6d11
#
#                                      md5  Machine  SizeOfOptionalHeader  \
# 41323   4a400b747afe6547e09ce0b02dae7f1c      332                   224
# 41324   9bd57c8252948bd2fa651ad372bd4f13      332                   224
# 41325   d1456165e9358b8f61f93a5f2042f39c      332                   224
# ...

# %%
legitimate=data[data['legitimate']==1]

# %%
legitimate
# Out:
#                Name                               md5  Machine  \
# 0       memtest.exe  631ea355665f28d4707448e442fbf5b8      332
# 1           ose.exe  9d10f99a6712e28f8acd5641e3a7ea6b      332
# 2         setup.exe  4d92f518527353c0db88a70fddcfd390      332
# 3          DW20.EXE  a41e524f8d45f0074fd07805ff0c9b12      332
# 4      dwtrig20.exe  c87e561258f2f8650cef999bf643a731      332
# ...             ...                               ...      ...
# 41318     mfc80.dll  1f5afd468eb5e09e9ed75a087529eab5      332
# 41319    mfc80u.dll  e2c48cd0132d4d1dc7d0df9a6bef686a      332
# 41320    mfcm80.dll  83362ee950ad18adb85b54409155c378      332
# 41321   mfcm80u.dll  26aafee5c30020c99120ee113d751f7e      332
# 41322     vcomp.dll  73dbaa64d589f3262615550dd6881fee      332
#
#        SizeOfOptionalHeader  Characteristics  MajorLinkerVersion  \
# 0                       224              258                   9
# 1                       224             3330                   9
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# Set the size of the figure
plt.figure(figsize=(10, 5))

# Histogram of individual player scores
sns.histplot(nonlegitimate['ImageBase'], bins=20, color='skyblue', edgecolor='black')
plt.title('ImageBase on nonlegitimate')
plt.xlabel('valu')
plt.ylabel('Frequency')

# Show the histogram
plt.show()
plt.figure(figsize=(10,5 ))

# Histogram of individual player scores
sns.histplot(legitimate['ImageBase'], bins=20, color='skyblue', edgecolor='black')
plt.title('ImageBase on legitimate')
plt.xlabel('valu')
plt.ylabel('Frequency')

# Show the histogram
plt.show()

# %%
plt.figure(figsize=(10, 5))

# Histogram of individual player scores
sns.histplot(nonlegitimate['MajorOperatingSystemVersion'], bins=20, color='skyblue', edgecolor='black')
plt.title('MajorOperatingSystemVersion on nonlegitimate')
plt.xlabel('valu')
plt.ylabel('Frequency')

# Show the histogram
plt.show()
plt.figure(figsize=(10,5 ))

# Histogram of individual player scores
sns.histplot(legitimate['MajorOperatingSystemVersion'], bins=20, color='skyblue', edgecolor='black')
plt.title('MajorOperatingSystemVersion on legitimate')
plt.xlabel('valu')
plt.ylabel('Frequency')

# Show the histogram
plt.show()

# %%
plt.figure(figsize=(10, 5))

# Histogram of individual player scores
sns.histplot(nonlegitimate['SizeOfStackReserve'], bins=20, color='skyblue', edgecolor='black')
plt.title('SizeOfStackReserve on nonlegitimate')
plt.xlabel('valu')
plt.ylabel('Frequency')

# Show the histogram
plt.show()
plt.figure(figsize=(10,5 ))

# Histogram of individual player scores
sns.histplot(legitimate['SizeOfStackReserve'], bins=20, color='skyblue', edgecolor='black')
plt.title('SizeOfStackReserve on legitimate')
plt.xlabel('valu')
plt.ylabel('Frequency')

# Show the histogram
plt.show()

# %%
plt.figure(figsize=(10, 5))

# Histogram of individual player scores
sns.histplot(nonlegitimate['Characteristics'], bins=20, color='skyblue', edgecolor='black')
plt.title('Characteristics on nonlegitimate')
plt.xlabel('valu')
plt.ylabel('Frequency')

# Show the histogram
plt.show()
plt.figure(figsize=(10,5 ))

# Histogram of individual player scores
sns.histplot(legitimate['Characteristics'], bins=20, color='skyblue', edgecolor='black')
plt.title('Characteristics on legitimate')
plt.xlabel('valu')
plt.ylabel('Frequency')

# Show the histogram
plt.show()

# %%
plt.figure(figsize=(10, 5))

# Histogram of individual player scores
sns.histplot(nonlegitimate['SizeOfInitializedData'], bins=20, color='skyblue', edgecolor='black')
plt.title('SizeOfInitializedData on nonlegitimate')
plt.xlabel('valu')
plt.ylabel('Frequency')

# Show the histogram
plt.show()
plt.figure(figsize=(10,5 ))

# Histogram of individual player scores
sns.histplot(legitimate['SizeOfInitializedData'], bins=20, color='skyblue', edgecolor='black')
plt.title('SizeOfInitializedData on legitimate')
plt.xlabel('valu')
plt.ylabel('Frequency')

# Show the histogram
plt.show()

# %%
nonlegitimate.columns
# Out:
# Index(['Name', 'md5', 'Machine', 'SizeOfOptionalHeader', 'Characteristics',
#        'MajorLinkerVersion', 'MinorLinkerVersion', 'SizeOfCode',
#        'SizeOfInitializedData', 'SizeOfUninitializedData',
#        'AddressOfEntryPoint', 'BaseOfCode', 'BaseOfData', 'ImageBase',
#        'SectionAlignment', 'FileAlignment', 'MajorOperatingSystemVersion',
#        'MinorOperatingSystemVersion', 'MajorImageVersion', 'MinorImageVersion',
#        'MajorSubsystemVersion', 'MinorSubsystemVersion', 'SizeOfImage',
#        'SizeOfHeaders', 'CheckSum', 'Subsystem', 'DllCharacteristics',
#        'SizeOfStackReserve', 'SizeOfStackCommit', 'SizeOfHeapReserve',
#        'SizeOfHeapCommit', 'LoaderFlags', 'NumberOfRvaAndSizes', 'SectionsNb',
#        'SectionsMeanEntropy', 'SectionsMinEntropy', 'SectionsMaxEntropy',
#        'SectionsMeanRawsize', 'SectionsMinRawsize', 'SectionMaxRawsize',
#        'SectionsMeanVirtualsize', 'SectionsMinVirtualsize',
# ...

# %%
plt.figure(figsize=(10, 5))

# Histogram of individual player scores
sns.histplot(nonlegitimate['MajorSubsystemVersion'], bins=20, color='skyblue', edgecolor='black')
plt.title('MajorSubsystemVersion on nonlegitimate')
plt.xlabel('valu')
plt.ylabel('Frequency')

# Show the histogram
plt.show()
plt.figure(figsize=(10,5 ))

# Histogram of individual player scores
sns.histplot(legitimate['MajorSubsystemVersion'], bins=20, color='skyblue', edgecolor='black')
plt.title('MajorSubsystemVersion on legitimate')
plt.xlabel('valu')
plt.ylabel('Frequency')

# Show the histogram
plt.show()

# %%
plt.figure(figsize=(10, 5))

# Histogram of individual player scores
sns.histplot(nonlegitimate['ResourcesNb'], bins=20, color='skyblue', edgecolor='black')
plt.title('ResourcesNb on nonlegitimate')
plt.xlabel('valu')
plt.ylabel('Frequency')

# Show the histogram
plt.show()
plt.figure(figsize=(10,5 ))

# Histogram of individual player scores
sns.histplot(legitimate['ResourcesNb'], bins=20, color='skyblue', edgecolor='black')
plt.title('ResourcesNb on legitimate')
plt.xlabel('valu')
plt.ylabel('Frequency')

# Show the histogram
plt.show()

# %%
plt.figure(figsize=(10, 5))

# Histogram of individual player scores
sns.histplot(nonlegitimate['Subsystem'], bins=20, color='skyblue', edgecolor='black')
plt.title('Subsystem on nonlegitimate')
plt.xlabel('valu')
plt.ylabel('Frequency')

# Show the histogram
plt.show()
plt.figure(figsize=(10,5 ))

# Histogram of individual player scores
sns.histplot(legitimate['Subsystem'], bins=20, color='skyblue', edgecolor='black')
plt.title('Subsystem on legitimate')
plt.xlabel('valu')
plt.ylabel('Frequency')

# Show the histogram
plt.show()

# %%
plt.figure(figsize=(10, 5))

# Histogram of individual player scores
sns.histplot(nonlegitimate['BaseOfData'], bins=20, color='skyblue', edgecolor='black')
plt.title('BaseOfData on nonlegitimate')
plt.xlabel('valu')
plt.ylabel('Frequency')

# Show the histogram
plt.show()
plt.figure(figsize=(10,5 ))

# Histogram of individual player scores
sns.histplot(legitimate['BaseOfData'], bins=20, color='skyblue', edgecolor='black')
plt.title('BaseOfData on legitimate')
plt.xlabel('valu')
plt.ylabel('Frequency')

# Show the histogram
plt.show()

# %%
nonlegitimate.columns
# Out:
# Index(['Name', 'md5', 'Machine', 'SizeOfOptionalHeader', 'Characteristics',
#        'MajorLinkerVersion', 'MinorLinkerVersion', 'SizeOfCode',
#        'SizeOfInitializedData', 'SizeOfUninitializedData',
#        'AddressOfEntryPoint', 'BaseOfCode', 'BaseOfData', 'ImageBase',
#        'SectionAlignment', 'FileAlignment', 'MajorOperatingSystemVersion',
#        'MinorOperatingSystemVersion', 'MajorImageVersion', 'MinorImageVersion',
#        'MajorSubsystemVersion', 'MinorSubsystemVersion', 'SizeOfImage',
#        'SizeOfHeaders', 'CheckSum', 'Subsystem', 'DllCharacteristics',
#        'SizeOfStackReserve', 'SizeOfStackCommit', 'SizeOfHeapReserve',
#        'SizeOfHeapCommit', 'LoaderFlags', 'NumberOfRvaAndSizes', 'SectionsNb',
#        'SectionsMeanEntropy', 'SectionsMinEntropy', 'SectionsMaxEntropy',
#        'SectionsMeanRawsize', 'SectionsMinRawsize', 'SectionMaxRawsize',
#        'SectionsMeanVirtualsize', 'SectionsMinVirtualsize',
# ...

# %%
plt.figure(figsize=(10, 5))

# Histogram of individual player scores
sns.histplot(nonlegitimate['SizeOfImage'], bins=20, color='skyblue', edgecolor='black')
plt.title('SizeOfImage on nonlegitimate')
plt.xlabel('valu')
plt.ylabel('Frequency')

# Show the histogram
plt.show()
plt.figure(figsize=(10,5 ))

# Histogram of individual player scores
sns.histplot(legitimate['SizeOfImage'], bins=20, color='skyblue', edgecolor='black')
plt.title('SizeOfImage on legitimate')
plt.xlabel('valu')
plt.ylabel('Frequency')

# Show the histogram
plt.show()

# %%
plt.figure(figsize=(10, 5))

# Histogram of individual player scores
sns.histplot(nonlegitimate['MajorLinkerVersion'], bins=20, color='skyblue', edgecolor='black')
plt.title('MajorLinkerVersion on nonlegitimate')
plt.xlabel('valu')
plt.ylabel('Frequency')

# Show the histogram
plt.show()
plt.figure(figsize=(10,5 ))

# Histogram of individual player scores
sns.histplot(legitimate['MajorLinkerVersion'], bins=20, color='skyblue', edgecolor='black')
plt.title('MajorLinkerVersion on legitimate')
plt.xlabel('valu')
plt.ylabel('Frequency')

# Show the histogram
plt.show()
